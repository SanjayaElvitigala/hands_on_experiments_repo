# %%
import datetime as dt
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd
import numpy as np

# %%
# Define the scope
scope = ['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']

# Add your service account credentials here
credentials = ServiceAccountCredentials.from_json_keyfile_name('credentials.json', scope,)

# Authorize the client
client = gspread.authorize(credentials)

# Open the Google Sheet by its title
worksheet = client.open('Testing_input').worksheet(title='Sheet1')

# Get the data as a list of lists
data = worksheet.get_all_values()

# Convert it into a pandas DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# %%
df
# Out:
#         2,3,7
# 0        date  description  dollars  salary  credits  in_hand  debits
# 1  09/20/2024        item1                      4000
# 2  08/20/2024        item2                                        300
# 3  07/20/2024        item3                                300
# 4  09/20/2024        item1                      4000
# 5  09/22/2024        item4            16000    16000

# %%
str_dt = '11/02/2024'

pd.to_datetime(str_dt)
# Out:
# Timestamp('2024-11-02 00:00:00')

# %%
worksheet.col_values(col=1)
# Out:
# ['2,3,7',
#  'date',
#  '09/20/2024',
#  '08/20/2024',
#  '07/20/2024',
#  '09/20/2024',
#  '09/22/2024']

# %%
dir(worksheet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_dimension_group',
#  '_auto_resize',
#  '_delete_dimension_group',
#  '_duplicate',
#  '_finder',
#  '_get_sheet_property',
#  '_hide_dimension',
#  '_list_cells',
#  '_properties',
#  '_set_gridlines_hidden_flag',
#  '_set_hidden_flag',
#  '_spreadsheet',
#  '_unhide_dimension',
#  'acell',
#  'add_cols',
#  'add_dimension_group_columns',
#  'add_dimension_group_rows',
#  'add_protected_range',
#  'add_rows',
#  'add_validation',
#  'append_row',
#  'append_rows',
#  'batch_clear',
#  'batch_format',
#  'batch_get',
#  'batch_update',
#  'cell',
#  'clear',
#  'clear_basic_filter',
#  'clear_note',
#  'clear_notes',
#  'clear_tab_color',
#  'client',
#  'col_count',
#  'col_values',
#  'column_count',
#  'columns_auto_resize',
#  'copy_range',
#  'copy_to',
#  'cut_range',
#  'define_named_range',
#  'delete_columns',
#  'delete_dimension',
#  'delete_dimension_group_columns',
#  'delete_dimension_group_rows',
#  'delete_named_range',
#  'delete_protected_range',
#  'delete_rows',
#  'duplicate',
#  'find',
#  'findall',
#  'format',
#  'freeze',
#  'frozen_col_count',
#  'frozen_row_count',
#  'get',
#  'get_all_cells',
#  'get_all_records',
#  'get_all_values',
#  'get_note',
#  'get_notes',
#  'get_tab_color',
#  'get_values',
#  'hide',
#  'hide_columns',
#  'hide_gridlines',
#  'hide_rows',
#  'id',
#  'index',
#  'insert_cols',
#  'insert_note',
#  'insert_notes',
#  'insert_row',
#  'insert_rows',
#  'isSheetHidden',
#  'is_gridlines_hidden',
#  'list_dimension_group_columns',
#  'list_dimension_group_rows',
#  'merge_cells',
#  'range',
#  'resize',
#  'row_count',
#  'row_values',
#  'rows_auto_resize',
#  'set_basic_filter',
#  'show',
#  'show_gridlines',
#  'sort',
#  'spreadsheet',
#  'spreadsheet_id',
#  'tab_color',
#  'title',
#  'unhide_columns',
#  'unhide_rows',
#  'unmerge_cells',
#  'update',
#  'update_acell',
#  'update_cell',
#  'update_cells',
#  'update_index',
#  'update_note',
#  'update_notes',
#  'update_tab_color',
#  'update_title',
#  'url']
